# %% [markdown]
# <a href="https://colab.research.google.com/github/Saf02Sam/general/blob/main/Saffa_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'name': ['Alice', 'Bob', 'Charlie', 'David'],'attempts': [3,2,2,1],'score': [90,85,83,79]}
df = pd.DataFrame(data)
filtered = df[(df['attempts'] < 2) & (df['score'] > 80)]
print(filtered)
# Out:
# Empty DataFrame
# Columns: [name, attempts, score]
# Index: []

# %%
df.at[2, 'score'] = 11.5
df
# Out:
#       name  attempts  score
# 0    Alice         3   90.0
# 1      Bob         2   85.0
# 2  Charlie         2   11.5
# 3    David         1   79.0

# %%
df['attempts'].sum()
# Out:
# 8

# %%
df.groupby('name')['score'].mean()
# Out:
# name
# Alice      90.0
# Bob        85.0
# Charlie    11.5
# David      79.0
# Name: score, dtype: float64

# %%
new_row = pd.DataFrame({'name': 'Ella', 'attempts': 3, 'score': 87}, index=['k'])
df = df.append(new_row)
df
# Out:
# <ipython-input-5-1de7019ded07>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row)
#       name  attempts  score
# 0    Alice         3   90.0
# 1      Bob         2   85.0
# 2  Charlie         2   11.5
# 3    David         1   79.0
# k     Ella         3   87.0

# %%
df = df.drop('k')
df
# Out:
#       name  attempts  score
# 0    Alice         3   90.0
# 1      Bob         2   85.0
# 2  Charlie         2   11.5
# 3    David         1   79.0

# %%
df.sort_values(by=['name', 'score'], ascending=[False, True])
# Out:
#       name  attempts  score
# 3    David         1   79.0
# 2  Charlie         2   11.5
# 1      Bob         2   85.0
# 0    Alice         3   90.0

# %%
data = {'name': ['Alice', 'Bob', 'Charlie', 'David'],'qualify': ['yes', 'no', 'yes', 'no'],'attempts': [3,2,2,1]}
df = pd.DataFrame(data)
df['qualify'] = df['qualify'].replace({'yes': True, 'no': False})
df
# Out:
#       name  qualify  attempts
# 0    Alice     True         3
# 1      Bob    False         2
# 2  Charlie     True         2
# 3    David    False         1

# %%
df['name'] = df['name'].replace('Alice','Anna')
print(df)
# Out:
#       name  qualify  attempts
# 0     Anna     True         3
# 1      Bob    False         2
# 2  Charlie     True         2
# 3    David    False         1

# %%
df.drop('attempts', axis=1)
# Out:
#       name  qualify
# 0     Anna     True
# 1      Bob    False
# 2  Charlie     True
# 3    David    False

# %%
df['grade'] = ['A', 'C', 'B', 'A']
df
# Out:
#       name  qualify  attempts grade
# 0     Anna     True         3     A
# 1      Bob    False         2     C
# 2  Charlie     True         2     B
# 3    David    False         1     A

# %%
for index, row in df.iterrows():
    print("Row index:", index)
    print("Name:", row['name'])
    print("Score:", row['grade'])
    print()
# Out:
# Row index: 0
# Name: Anna
# Score: A
#
# Row index: 1
# Name: Bob
# Score: C
#
# Row index: 2
# Name: Charlie
# Score: B
#
# Row index: 3
# Name: David
# Score: A

# %%
import numpy as np
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'score': [20, np.nan, 18, np.nan],
    'age': [25, 30, np.nan, np.nan]
}
df = pd.DataFrame(data)
nan_score = df['score'].isna().sum()

print(nan_score)
nan= df[['score', 'age']].isna().sum()
print(nan)
# Out:
# 2
# score    2
# age      2
# dtype: int64

# %%
d = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
df = pd.DataFrame(d)
df.columns = df.columns.str.upper()
df.columns = df.columns + '_'
print(df)
# Out:
#    COL1_  COL2_  COL3_
# 0      1      4      7
# 1      2      5      8
# 2      3      6      9

# %%
df[df.eq(4).any(axis=1)]
# Out:
#    COL1_  COL2_  COL3_
# 0      1      4      7

# %%
df.loc[:, ::-1]
# Out:
#    COL3_  COL2_  COL1_
# 0      7      4      1
# 1      8      5      2
# 2      9      6      3

# %%
new_row = {'COL1_': 3, 'COL2_': 2, 'COL3_': 4}
df.append(new_row, ignore_index=True)
# Out:
# <ipython-input-33-d87966bdccb1>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row, ignore_index=True)
#    COL1_  COL2_  COL3_
# 0      1      4      7
# 1      2      5      8
# 2      3      6      9
# 3      3      2      4

# %%
df[~df.eq(5).any(axis=1)]
# Out:
#    COL1_  COL2_  COL3_
# 0      1      4      7
# 2      3      6      9
