# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]
y=[2,4,1,6,8,3]
plt.xlabel('Days')
plt.ylabel('Stocks')
plt.plot(x,y,marker='o',linestyle=':',color='#91265f',linewidth=0.5)
plt.title('Sensex')
plt.grid(axis='y')
plt.show()

# %%
import numpy as np

# %%
x=np.array([13,63,24,72,62,37])
y=np.array([24,14,54,15,4,29])
z=np.array([1,5,2,6,8,3])
plt.plot(x,label='x')
plt.plot(y,label='y')
plt.plot(z,label='z')
plt.grid(axis='y')
plt.show()

# %%
#plot 1
x=np.array([1,2,3,4,5,6])
y=np.array([11,32,63,21,15,25])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot 2
a=np.array([2,3,5,15,23,6])
z=np.array([42,2,52,61,34,13])
plt.subplot(1,2,2)
plt.plot(a,z)
plt.show()

# %%
x=[1,2,3,4,5]
y=[4,14,7,1,4]
plt.scatter(x,y)
z=[2,3,5,6,7]
a=[4,6,10,12,14]
c=['green']*(len(a)-1)
c.append('red')
print(c)
plt.scatter(z,a,color=c)
plt.show()
# Out:
# ['green', 'green', 'green', 'green', 'red']

# %%
plt.bar(x,y,color='teal')
plt.show()

# %%
import random

# %%
x=random.randint(1,200,50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-8f214cf66677> in <cell line: 1>()
# ----> 1 x=random.randint(1,200,50)
#
# TypeError: Random.randint() takes 3 positional arguments but 4 were given

# %%
plt.pie(a)
plt.show()

# %%
data = {'Capitals': ['PANAJI', 'CHANDIGARH', 'PATNA', 'AGARTALA'],

      'Population': ['1,347,668', '21,144,564', '82,998,509','3,199,203'],

      'States': ['GOA', 'HARYANA', 'BIHAR', 'TRIPURA'],

      'Visitors': [300, 4000, 50, 80000],

      'area' : ["3,702", "44,212" ,"94,163", "10,486"]}

# %%
import pandas as pd
d=pd.DataFrame(data)
d
# Out:
#      Capitals  Population   States  Visitors    area
# 0      PANAJI   1,347,668      GOA       300   3,702
# 1  CHANDIGARH  21,144,564  HARYANA      4000  44,212
# 2       PATNA  82,998,509    BIHAR        50  94,163
# 3    AGARTALA   3,199,203  TRIPURA     80000  10,486

# %%
d=d.set_index('area')

# %%
d=d.reset_index()
d
# Out:
#      area    Capitals  Population   States  Visitors
# 0   3,702      PANAJI   1,347,668      GOA       300
# 1  44,212  CHANDIGARH  21,144,564  HARYANA      4000
# 2  94,163       PATNA  82,998,509    BIHAR        50
# 3  10,486    AGARTALA   3,199,203  TRIPURA     80000

# %%
d.columns
# Out:
# Index(['area', 'Capitals', 'Population', 'States', 'Visitors'], dtype='object')

# %%
d=d.drop(['index'],axis=1)
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-e40618017196> in <cell line: 1>()
# ----> 1 d=d.drop(['index'],axis=1)
#       2 d
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
re=d.T
re
# Out:
#                     0           1           2          3
# area            3,702      44,212      94,163     10,486
# Capitals       PANAJI  CHANDIGARH       PATNA   AGARTALA
# Population  1,347,668  21,144,564  82,998,509  3,199,203
# States            GOA     HARYANA       BIHAR    TRIPURA
# Visitors          300        4000          50      80000

# %%
d
# Out:
#      area    Capitals  Population   States  Visitors
# 0   3,702      PANAJI   1,347,668      GOA       300
# 1  44,212  CHANDIGARH  21,144,564  HARYANA      4000
# 2  94,163       PATNA  82,998,509    BIHAR        50
# 3  10,486    AGARTALA   3,199,203  TRIPURA     80000

# %%
d['Visitors'].sum()
# Out:
# 84350

# %%
d['Visitors'][2]=5000
# Out:
# <ipython-input-119-59f3bfc3961c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Visitors'][2]=5000

# %%
d
# Out:
#      area    Capitals  Population   States  Visitors
# 0   3,702      PANAJI   1,347,668      GOA       300
# 1  44,212  CHANDIGARH  21,144,564  HARYANA      4000
# 2  94,163       PATNA  82,998,509    BIHAR      5000
# 3  10,486    AGARTALA   3,199,203  TRIPURA     80000

# %%
a=pd.Series(["Tesla",np.NaN,"Audi",np.NaN,np.NaN,"Benz",np.NaN,"Tata",np.NaN,np.NaN])
a
# Out:
# 0    Tesla
# 1      NaN
# 2     Audi
# 3      NaN
# 4      NaN
# 5     Benz
# 6      NaN
# 7     Tata
# 8      NaN
# 9      NaN
# dtype: object

# %%
a.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
a.isna().sum()
# Out:
# 6

# %%
a.drop([2,3,4])
# Out:
# 0    Tesla
# 1      NaN
# 5     Benz
# 6      NaN
# 7     Tata
# 8      NaN
# 9      NaN
# dtype: object

# %%
a.dropna()
# Out:
# 0    Tesla
# 2     Audi
# 5     Benz
# 7     Tata
# dtype: object

# %%
a.fillna(10)
# Out:
# 0    Tesla
# 1       10
# 2     Audi
# 3       10
# 4       10
# 5     Benz
# 6       10
# 7     Tata
# 8       10
# 9       10
# dtype: object

# %%
a.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
a[a.duplicated()]
# Out:
# 3    NaN
# 4    NaN
# 6    NaN
# 8    NaN
# 9    NaN
# dtype: object

# %%
a.unique()
# Out:
# array(['Tesla', nan, 'Audi', 'Benz', 'Tata'], dtype=object)

# %%
a.replace(np.NaN,5)
# Out:
# 0    Tesla
# 1        5
# 2     Audi
# 3        5
# 4        5
# 5     Benz
# 6        5
# 7     Tata
# 8        5
# 9        5
# dtype: object

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
x=pd.DataFrame(exam_data,index=labels)

# %%
x
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
x.insert(2,'states',0)
#insert(pos,col_name,val)
x
# Out:
#         name  score  states  attempts qualify
# a  Anastasia   12.5       0         1     yes
# b       Dima    9.0       0         3      no
# c  Katherine   16.5       0         2     yes
# d      James    NaN       0         3      no
# e      Emily    9.0       0         2      no
# f    Michael   20.0       0         3     yes
# g    Matthew   14.5       0         1     yes
# h      Laura    NaN       0         1      no
# i      Kevin    8.0       0         2      no
# j      Jonas   19.0       0         1     yes

# %%
y=x.head(3)
y
# Out:
#         name  score  states  attempts qualify
# a  Anastasia   12.5       0         1     yes
# b       Dima    9.0       0         3      no
# c  Katherine   16.5       0         2     yes

# %%
z=pd.DataFrame((x['name'],x['score']))
z.T
# Out:
#         name score
# a  Anastasia  12.5
# b       Dima   9.0
# c  Katherine  16.5
# d      James   NaN
# e      Emily   9.0
# f    Michael  20.0
# g    Matthew  14.5
# h      Laura   NaN
# i      Kevin   8.0
# j      Jonas  19.0

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   states    10 non-null     int64
#  3   attempts  10 non-null     int64
#  4   qualify   10 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 780.0+ bytes

# %%
pd.DataFrame(x['qualify'].tail())
# Out:
#   qualify
# f     yes
# g     yes
# h      no
# i      no
# j     yes

# %%
pd.DataFrame(x['attempts'].where(x['attempts']>2)).dropna()
# Out:
#    attempts
# b       3.0
# d       3.0
# f       3.0

# %%
pd.DataFrame(x.where(x.isna()==False)).dropna()
# Out:
#         name  score  states  attempts qualify
# a  Anastasia   12.5       0         1     yes
# b       Dima    9.0       0         3      no
# c  Katherine   16.5       0         2     yes
# e      Emily    9.0       0         2      no
# f    Michael   20.0       0         3     yes
# g    Matthew   14.5       0         1     yes
# i      Kevin    8.0       0         2      no
# j      Jonas   19.0       0         1     yes

# %%
c=0
for col in x:
  c+=1
print(c)
r=0
for el in x['name']:
  r+=1
print(r)
# Out:
# 5
# 10

# %%
pd.DataFrame(x.where((x['score'].between(15,20)))).dropna()
# Out:
#         name  score  states  attempts qualify
# c  Katherine   16.5     0.0       2.0     yes
# f    Michael   20.0     0.0       3.0     yes
# j      Jonas   19.0     0.0       1.0     yes

# %%
x1=pd.DataFrame(x.where(x['attempts']<2)).dropna()
pd.DataFrame(x1.where(x1['score']>15)).dropna()
# Out:
#     name  score  states  attempts qualify
# j  Jonas   19.0     0.0       1.0     yes

# %%
x['score']['d']=11.5
x
# Out:
# <ipython-input-378-e655bbad1486>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['score']['d']=11.5
#         name  score  states  attempts qualify
# a  Anastasia   12.5       0         1     yes
# b       Dima    9.0       0         3      no
# c  Katherine   16.5       0         2     yes
# d      James   11.5       0         3      no
# e      Emily    9.0       0         2      no
# f    Michael   20.0       0         3     yes
# g    Matthew   14.5       0         1     yes
# h      Laura    NaN       0         1      no
# i      Kevin    8.0       0         2      no
# j      Jonas   19.0       0         1     yes

# %%
x['attempts'].sum()
# Out:
# 19

# %%
x['mean']=x['score']/x['attempts']
x
# Out:
#         name  score  states  attempts qualify       mean
# a  Anastasia   12.5       0         1     yes  12.500000
# b       Dima    9.0       0         3      no   3.000000
# c  Katherine   16.5       0         2     yes   8.250000
# d      James   11.5       0         3      no   3.833333
# e      Emily    9.0       0         2      no   4.500000
# f    Michael   20.0       0         3     yes   6.666667
# g    Matthew   14.5       0         1     yes  14.500000
# h      Laura    NaN       0         1      no        NaN
# i      Kevin    8.0       0         2      no   4.000000
# j      Jonas   19.0       0         1     yes  19.000000

# %%
x['k']=[1,2,3,4,5,6,7,8,9,0]
x
# Out:
#         name  score  states  attempts qualify       mean  k
# a  Anastasia   12.5       0         1     yes  12.500000  1
# b       Dima    9.0       0         3      no   3.000000  2
# c  Katherine   16.5       0         2     yes   8.250000  3
# d      James   11.5       0         3      no   3.833333  4
# e      Emily    9.0       0         2      no   4.500000  5
# f    Michael   20.0       0         3     yes   6.666667  6
# g    Matthew   14.5       0         1     yes  14.500000  7
# h      Laura    NaN       0         1      no        NaN  8
# i      Kevin    8.0       0         2      no   4.000000  9
# j      Jonas   19.0       0         1     yes  19.000000  0

# %%
x=x.drop('k',axis=1)
x
# Out:
#         name  score  states  attempts qualify       mean
# a  Anastasia   12.5       0         1     yes  12.500000
# b       Dima    9.0       0         3      no   3.000000
# c  Katherine   16.5       0         2     yes   8.250000
# d      James   11.5       0         3      no   3.833333
# e      Emily    9.0       0         2      no   4.500000
# f    Michael   20.0       0         3     yes   6.666667
# g    Matthew   14.5       0         1     yes  14.500000
# h      Laura    NaN       0         1      no        NaN
# i      Kevin    8.0       0         2      no   4.000000
# j      Jonas   19.0       0         1     yes  19.000000

# %%
x.sort_values(by=['name'],ascending=False)
# Out:
#         name  score  states  attempts qualify       mean
# f    Michael   20.0       0         3     yes   6.666667
# g    Matthew   14.5       0         1     yes  14.500000
# h      Laura    NaN       0         1      no        NaN
# i      Kevin    8.0       0         2      no   4.000000
# c  Katherine   16.5       0         2     yes   8.250000
# j      Jonas   19.0       0         1     yes  19.000000
# d      James   11.5       0         3      no   3.833333
# e      Emily    9.0       0         2      no   4.500000
# b       Dima    9.0       0         3      no   3.000000
# a  Anastasia   12.5       0         1     yes  12.500000

# %%
x.sort_values(by=['score'],ascending=True)
# Out:
#         name  score  states  attempts qualify       mean
# i      Kevin    8.0       0         2      no   4.000000
# b       Dima    9.0       0         3      no   3.000000
# e      Emily    9.0       0         2      no   4.500000
# d      James   11.5       0         3      no   3.833333
# a  Anastasia   12.5       0         1     yes  12.500000
# g    Matthew   14.5       0         1     yes  14.500000
# c  Katherine   16.5       0         2     yes   8.250000
# j      Jonas   19.0       0         1     yes  19.000000
# f    Michael   20.0       0         3     yes   6.666667
# h      Laura    NaN       0         1      no        NaN

# %%
x.replace({'yes':True,'no':False},inplace=True)

# %%
x
# Out:
#         name  score  states  attempts  qualify       mean
# a  Anastasia   12.5       0         1     True  12.500000
# b       Dima    9.0       0         3    False   3.000000
# c  Katherine   16.5       0         2     True   8.250000
# d      James   11.5       0         3    False   3.833333
# e      Emily    9.0       0         2    False   4.500000
# f    Michael   20.0       0         3     True   6.666667
# g    Matthew   14.5       0         1     True  14.500000
# h      Laura    NaN       0         1    False        NaN
# i      Kevin    8.0       0         2    False   4.000000
# j      Jonas   19.0       0         1     True  19.000000

# %%
x['name']=x['name'].replace(to_replace='James',value='Suresh')

# %%
x
# Out:
#         name  score  states  attempts  qualify       mean
# a  Anastasia   12.5       0         1     True  12.500000
# b       Dima    9.0       0         3    False   3.000000
# c  Katherine   16.5       0         2     True   8.250000
# d     Suresh   11.5       0         3    False   3.833333
# e      Emily    9.0       0         2    False   4.500000
# f    Michael   20.0       0         3     True   6.666667
# g    Matthew   14.5       0         1     True  14.500000
# h      Laura    NaN       0         1    False        NaN
# i      Kevin    8.0       0         2    False   4.000000
# j      Jonas   19.0       0         1     True  19.000000

# %%
x=x.drop('attempts',axis=1)

# %%
x
# Out:
#         name  score  states  qualify       mean
# a  Anastasia   12.5       0     True  12.500000
# b       Dima    9.0       0    False   3.000000
# c  Katherine   16.5       0     True   8.250000
# d     Suresh   11.5       0    False   3.833333
# e      Emily    9.0       0    False   4.500000
# f    Michael   20.0       0     True   6.666667
# g    Matthew   14.5       0     True  14.500000
# h      Laura    NaN       0    False        NaN
# i      Kevin    8.0       0    False   4.000000
# j      Jonas   19.0       0     True  19.000000

# %%
x['new']=0

# %%
x
# Out:
#         name  score  states  qualify       mean  new
# a  Anastasia   12.5       0     True  12.500000    0
# b       Dima    9.0       0    False   3.000000    0
# c  Katherine   16.5       0     True   8.250000    0
# d     Suresh   11.5       0    False   3.833333    0
# e      Emily    9.0       0    False   4.500000    0
# f    Michael   20.0       0     True   6.666667    0
# g    Matthew   14.5       0     True  14.500000    0
# h      Laura    NaN       0    False        NaN    0
# i      Kevin    8.0       0    False   4.000000    0
# j      Jonas   19.0       0     True  19.000000    0

# %%
for el in x.index:
  print(x['name'][el])
# Out:
# Anastasia
# Dima
# Katherine
# Suresh
# Emily
# Michael
# Matthew
# Laura
# Kevin
# Jonas

# %%
p=0
for l in x.columns:
  p+=x[l].isna().sum()
print(p)
# Out:
# 2

# %%
y=[]
z=[]
for l in x.columns:
  z.append(l)
  y.append(l.upper())
d={z[i]: y[i] for i in range(len(z))}
x.rename(columns=d,inplace=True)
x
# Out:
#         NAME  SCORE  STATES  QUALIFY       MEAN  NEW
# a  Anastasia   12.5       0     True  12.500000    0
# b       Dima    9.0       0    False   3.000000    0
# c  Katherine   16.5       0     True   8.250000    0
# d     Suresh   11.5       0    False   3.833333    0
# e      Emily    9.0       0    False   4.500000    0
# f    Michael   20.0       0     True   6.666667    0
# g    Matthew   14.5       0     True  14.500000    0
# h      Laura    NaN       0    False        NaN    0
# i      Kevin    8.0       0    False   4.000000    0
# j      Jonas   19.0       0     True  19.000000    0

# %%
y=[]
z=[]
for l in x.columns:
  z.append(l)
  y.append(l+'_')
d={z[i]: y[i] for i in range(len(z))}
x.rename(columns=d,inplace=True)
x
# Out:
#        NAME_  SCORE_  STATES_  QUALIFY_      MEAN_  NEW_
# a  Anastasia    12.5        0      True  12.500000     0
# b       Dima     9.0        0     False   3.000000     0
# c  Katherine    16.5        0      True   8.250000     0
# d     Suresh    11.5        0     False   3.833333     0
# e      Emily     9.0        0     False   4.500000     0
# f    Michael    20.0        0      True   6.666667     0
# g    Matthew    14.5        0      True  14.500000     0
# h      Laura     NaN        0     False        NaN     0
# i      Kevin     8.0        0     False   4.000000     0
# j      Jonas    19.0        0      True  19.000000     0
